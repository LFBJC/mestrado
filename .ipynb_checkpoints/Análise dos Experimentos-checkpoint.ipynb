# %%
import os
import pandas as pd
pasta_mestrado = 'E:/mestrado/Pesquisa/Dados simulados'
redes = ['CNN', 'LSTM']
caminho_var = f'{pasta_mestrado}/resultados VAR.csv'
steps_ahead_list = [1, 5, 20]

# %%
datasets = {}
paths = {}
for rede in redes:
    datasets[rede] = {}
    paths[rede] = {}
    data_indices = set()
    for steps_ahead in steps_ahead_list:
        paths[rede][steps_ahead] = f'{pasta_mestrado}/Saída da otimização de hiperparâmetros {rede}/{steps_ahead} steps ahead'
        current_data_indices = set(os.listdir(paths[rede][steps_ahead]))
        if data_indices == set():
            data_indices = current_data_indices
        else:
            data_indices = data_indices.intersection(current_data_indices)
        datasets[rede][steps_ahead] = pd.DataFrame()
    for data_index in data_indices:
        for steps_ahead in steps_ahead_list:
            current_df = pd.read_csv(f'{paths[rede][steps_ahead]}/{data_index}/opt_hist.csv')
            current_df['data_set_index'] = data_index
            datasets[rede][steps_ahead] = pd.concat([datasets[rede][steps_ahead], current_df])
            del current_df

# %%
datasets
# Out:
# {'CNN': {1:     win_size  filters_conv_1  kernel_size_conv_1[0]  kernel_size_conv_1[1]  \
#   0         30              33                     10                      3
#   1         88              50                     17                      3
#   2          6              37                      1                      2
#   3         23              32                      6                      2
#   4         80              28                     25                      2
#   ..       ...             ...                    ...                    ...
#   95        36              32                     11                      4
#   96       111              33                     23                      2
#   97        46              35                     13                      4
#   98        59              37                     14                      4
#   99        42              35                     12                      4
#
#      activation_conv_1  pool_size_1[0] pool_type_1  filters_conv_2  \
#   0                elu               4     average               8
#   1                elu              24     average              21
#   2            sigmoid               1     average              11
#   3              swish               5     average              15
#   4             linear              15         max               9
#   ..               ...             ...         ...             ...
#   95             swish              11     average              11
#   96              tanh              43     average              15
#   97              tanh              14     average              13
#   98              tanh              20     average              14
#   99              relu              14     average              13
#
#       kernel_size_conv_2[0] activation_conv_2  dense_neurons optimizer  \
#   0                       4              relu             36  adadelta
#   1                       2              relu             80       sgd
#   2                       4            linear             20       sgd
#   3                       2              relu            100   adagrad
#   4                       1               elu             54      adam
#   ..                    ...               ...            ...       ...
#   95                      1           sigmoid             32      adam
#   96                      1           sigmoid             99  adadelta
#   97                      1           sigmoid             21      adam
#   98                      1               elu             21   rmsprop
#   99                      1              relu             25      adam
#
#                                 loss  w2  w3  w4  h4      score data_set_index
#   0               mean_squared_error  21   5   2   3   8.853666              7
#   1               mean_squared_error  72   3   2   3   5.761912              7
#   2   mean_absolute_percentage_error   6   6   3   4   0.998768              7
#   3              mean_absolute_error  18   3   2   4  13.646652              7
#   4   mean_absolute_percentage_error  56   3   3   4   9.423500              7
#   ..                             ...  ..  ..  ..  ..        ...            ...
#   95  mean_squared_logarithmic_error  26   2   2   2   0.745477              4
#   96              mean_squared_error  89   2   2   4   0.747836              4
#   97  mean_squared_logarithmic_error  34   2   2   2   0.661405              4
#   98  mean_squared_logarithmic_error  46   2   2   2   0.751631              4
#   99  mean_absolute_percentage_error  31   2   2   2   0.703152              4
#
#   [1000 rows x 19 columns],
#   5:     win_size  filters_conv_1  kernel_size_conv_1[0]  kernel_size_conv_1[1]  \
#   0         89              39                     24                      4
#   1         61              17                     15                      5
#   2         35              46                      8                      5
#   3         58              32                     12                      3
#   4          6              29                      1                      4
#   ..       ...             ...                    ...                    ...
#   95       109              39                     36                      2
#   96        95              44                     25                      2
#   97        36              47                     11                      2
#   98        68              42                     20                      2
#   99        71              42                     21                      2
#
#      activation_conv_1  pool_size_1[0] pool_type_1  filters_conv_2  \
#   0              swish              24     average               6
#   1             linear              11         max               7
#   2                elu              11     average              11
#   3             linear              20     average               7
#   4            sigmoid               3     average              11
#   ..               ...             ...         ...             ...
#   95           sigmoid              35     average              18
#   96           sigmoid              34     average              19
#   97           sigmoid              11     average              20
#   98           sigmoid              23     average              19
#   99           sigmoid              24     average              19
#
#       kernel_size_conv_2[0] activation_conv_2  dense_neurons optimizer  \
#   0                       1            linear              5      adam
#   1                       2              relu              7   adagrad
#   2                       1              relu              8  adadelta
#   3                       1              tanh             38  adadelta
#   4                       1              relu             21  adadelta
#   ..                    ...               ...            ...       ...
#   95                      1              relu             99      adam
#   96                      1              relu            104      adam
#   97                      1              relu            113      adam
#   98                      1              relu             96      adam
#   99                      1              relu             96      adam
#
#                                 loss  w2  w3  w4  h4     score data_set_index
#   0   mean_absolute_percentage_error  66   2   2   2  9.856533              7
#   1   mean_squared_logarithmic_error  47   4   3   1  1.809250              7
#   2               mean_squared_error  28   2   2   1  8.205187              7
#   3   mean_absolute_percentage_error  47   2   2   3  9.145754              7
#   4              mean_absolute_error   6   2   2   2  7.357590              7
#   ..                             ...  ..  ..  ..  ..       ...            ...
#   95  mean_squared_logarithmic_error  74   2   2   4  0.722488              4
#   96  mean_squared_logarithmic_error  71   2   2   4  0.719196              4
#   97  mean_squared_logarithmic_error  26   2   2   4  0.652232              4
#   98  mean_squared_logarithmic_error  49   2   2   4  0.635275              4
#   99  mean_squared_logarithmic_error  51   2   2   4  0.720304              4
#
#   [1000 rows x 19 columns],
#   20:     win_size  filters_conv_1  kernel_size_conv_1[0]  kernel_size_conv_1[1]  \
#   0         95              43                     21                      2
#   1         13              27                      2                      2
#   2        103              13                     23                      1
#   3         66              19                     15                      4
#   4         71              46                     20                      5
#   ..       ...             ...                    ...                    ...
#   95        98              37                     22                      1
#   96       103              42                     23                      1
#   97        47              45                     12                      1
#   98       116              15                     27                      1
#   99        54              34                     13                      1
#
#      activation_conv_1  pool_size_1[0] pool_type_1  filters_conv_2  \
#   0              swish              30         max               6
#   1            sigmoid               3         max               9
#   2              swish              24         max               6
#   3                elu               5         max               7
#   4               relu               5         max              15
#   ..               ...             ...         ...             ...
#   95           sigmoid              36     average              14
#   96              tanh              31     average              19
#   97              tanh               9     average              21
#   98              tanh              21     average               6
#   99           sigmoid              16     average              13
#
#       kernel_size_conv_2[0] activation_conv_2  dense_neurons optimizer  \
#   0                       1             swish             37      adam
#   1                       1               elu             52      adam
#   2                       1              tanh              7   rmsprop
#   3                       5             swish             28      adam
#   4                       1              tanh            140   adagrad
#   ..                    ...               ...            ...       ...
#   95                      1               elu             52   rmsprop
#   96                      1              relu             50  adadelta
#   97                      2              relu             15   rmsprop
#   98                      2              relu             59   adagrad
#   99                      1               elu             43   rmsprop
#
#                                 loss  w2  w3  w4  h4      score data_set_index
#   0   mean_squared_logarithmic_error  75   2   2   4   2.286325              7
#   1              mean_absolute_error  12   4   4   4  23.452723              7
#   2              mean_absolute_error  81   3   3   5   2.115166              7
#   3   mean_squared_logarithmic_error  52  10   6   2   2.047867              7
#   4   mean_absolute_percentage_error  52  10  10   1  70.479079              7
#   ..                             ...  ..  ..  ..  ..        ...            ...
#   95             mean_absolute_error  77   2   2   5   0.710779              4
#   96              mean_squared_error  81   2   2   5   0.662373              4
#   97  mean_squared_logarithmic_error  36   4   3   5   0.727224              4
#   98  mean_squared_logarithmic_error  90   4   3   5   0.756261              4
#   99  mean_squared_logarithmic_error  42   2   2   5   0.721743              4
#
#   [1000 rows x 19 columns]},
#  'LSTM': {1:     win_size  Número de camadas  Unidades na camada 0  Dropout da camada 0  \
#   0          9                  2                    48             0.480446
#   1         29                  1                     8             0.395262
#   2         55                  1                    24             0.441379
#   3        116                  1                    59             0.406658
#   4        108                  4                    27             0.149439
#   ..       ...                ...                   ...                  ...
#   95        43                  4                    54             0.366528
#   96        53                  4                    58             0.366064
#   97        53                  5                    58             0.351834
#   98        66                  4                    55             0.373197
#   99        42                  4                    53             0.367146
#
#       Dropout recorrente da camada 0  Unidades na camada 1  Dropout da camada 1  \
#   0                         0.129988                   3.0             0.232030
#   1                         0.448327                   NaN                  NaN
#   2                         0.154746                   NaN                  NaN
#   3                         0.460818                   NaN                  NaN
#   4                         0.250830                  19.0             0.482007
#   ..                             ...                   ...                  ...
#   95                        0.413987                  51.0             0.277955
#   96                        0.416886                  55.0             0.254125
#   97                        0.414712                  55.0             0.273813
#   98                        0.431076                  51.0             0.260627
#   99                        0.405995                  52.0             0.252966
#
#       Dropout recorrente da camada 1 optimizer                            loss  \
#   0                         0.291605   adagrad  mean_squared_logarithmic_error
#   1                              NaN   adagrad  mean_squared_logarithmic_error
#   2                              NaN      adam             mean_absolute_error
#   3                              NaN  adadelta              mean_squared_error
#   4                         0.136510      adam             mean_absolute_error
#   ..                             ...       ...                             ...
#   95                        0.108478      adam             mean_absolute_error
#   96                        0.114558      adam             mean_absolute_error
#   97                        0.111780      adam             mean_absolute_error
#   98                        0.171490      adam             mean_absolute_error
#   99                        0.157579      adam             mean_absolute_error
#
#       ...  Unidades na camada 2  Dropout da camada 2  \
#   0   ...                   NaN                  NaN
#   1   ...                   NaN                  NaN
#   2   ...                   NaN                  NaN
#   3   ...                   NaN                  NaN
#   4   ...                   6.0             0.421833
#   ..  ...                   ...                  ...
#   95  ...                  49.0             0.199229
#   96  ...                  50.0             0.159016
#   97  ...                  50.0             0.164267
#   98  ...                  49.0             0.158017
#   99  ...                  46.0             0.184061
#
#       Dropout recorrente da camada 2  Unidades na camada 3  Dropout da camada 3  \
#   0                              NaN                   NaN                  NaN
#   1                              NaN                   NaN                  NaN
#   2                              NaN                   NaN                  NaN
#   3                              NaN                   NaN                  NaN
#   4                         0.161558                   6.0             0.432769
#   ..                             ...                   ...                  ...
#   95                        0.159946                  29.0             0.414400
#   96                        0.157602                  45.0             0.414525
#   97                        0.156103                  49.0             0.370124
#   98                        0.196959                  23.0             0.393367
#   99                        0.159650                  39.0             0.425373
#
#       Dropout recorrente da camada 3  Unidades na camada 4  Dropout da camada 4  \
#   0                              NaN                   NaN                  NaN
#   1                              NaN                   NaN                  NaN
#   2                              NaN                   NaN                  NaN
#   3                              NaN                   NaN                  NaN
#   4                         0.120436                   NaN                  NaN
#   ..                             ...                   ...                  ...
#   95                        0.311382                   NaN                  NaN
#   96                        0.313659                   NaN                  NaN
#   97                        0.308781                  21.0              0.35671
#   98                        0.313002                   NaN                  NaN
#   99                        0.292464                   NaN                  NaN
#
#       Dropout recorrente da camada 4  data_set_index
#   0                              NaN               7
#   1                              NaN               7
#   2                              NaN               7
#   3                              NaN               7
#   4                              NaN               7
#   ..                             ...             ...
#   95                             NaN               4
#   96                             NaN               4
#   97                        0.397843               4
#   98                             NaN               4
#   99                             NaN               4
#
#   [1000 rows x 21 columns],
#   5:     win_size  Número de camadas  Unidades na camada 0  Dropout da camada 0  \
#   0         82                  5                    40             0.372236
#   1         67                  3                    14             0.208752
#   2         96                  1                    43             0.243935
#   3         53                  5                    20             0.314935
#   4         11                  2                    10             0.152756
#   ..       ...                ...                   ...                  ...
#   95        38                  5                    59             0.124832
#   96        19                  5                    56             0.107095
#   97        25                  4                    63             0.138781
#   98        14                  5                    61             0.161691
#   99        11                  5                    29             0.150731
#
#       Dropout recorrente da camada 0  Unidades na camada 1  Dropout da camada 1  \
#   0                         0.400252                  23.0             0.171274
#   1                         0.364887                  14.0             0.311507
#   2                         0.446775                   NaN                  NaN
#   3                         0.231163                   8.0             0.178561
#   4                         0.397726                   4.0             0.362623
#   ..                             ...                   ...                  ...
#   95                        0.415195                  57.0             0.295969
#   96                        0.313124                  54.0             0.329152
#   97                        0.391659                  62.0             0.269932
#   98                        0.403961                  59.0             0.315136
#   99                        0.366511                  23.0             0.286153
#
#       Dropout recorrente da camada 1  Unidades na camada 2  Dropout da camada 2  \
#   0                         0.362789                  17.0             0.455424
#   1                         0.335974                   7.0             0.310307
#   2                              NaN                   NaN                  NaN
#   3                         0.335105                   4.0             0.369762
#   4                         0.388549                   NaN                  NaN
#   ..                             ...                   ...                  ...
#   95                        0.319929                  55.0             0.279398
#   96                        0.384146                  52.0             0.302766
#   97                        0.333959                  61.0             0.244989
#   98                        0.360460                  49.0             0.223443
#   99                        0.347114                  16.0             0.262049
#
#       ...  Unidades na camada 3  Dropout da camada 3  \
#   0   ...                  17.0             0.388872
#   1   ...                   NaN                  NaN
#   2   ...                   NaN                  NaN
#   3   ...                   3.0             0.323053
#   4   ...                   NaN                  NaN
#   ..  ...                   ...                  ...
#   95  ...                  53.0             0.310271
#   96  ...                  49.0             0.363364
#   97  ...                  59.0             0.343757
#   98  ...                  47.0             0.485549
#   99  ...                  15.0             0.300326
#
#       Dropout recorrente da camada 3  Unidades na camada 4  Dropout da camada 4  \
#   0                         0.105486                  16.0             0.151879
#   1                              NaN                   NaN                  NaN
#   2                              NaN                   NaN                  NaN
#   3                         0.163116                   3.0             0.262104
#   4                              NaN                   NaN                  NaN
#   ..                             ...                   ...                  ...
#   95                        0.266125                  33.0             0.329055
#   96                        0.232644                  30.0             0.351717
#   97                        0.305839                   NaN                  NaN
#   98                        0.274990                  37.0             0.364585
#   99                        0.246617                  14.0             0.306752
#
#       Dropout recorrente da camada 4  optimizer                            loss  \
#   0                         0.313562    adagrad             mean_absolute_error
#   1                              NaN        sgd  mean_absolute_percentage_error
#   2                              NaN   adadelta  mean_squared_logarithmic_error
#   3                         0.146677   adadelta             mean_absolute_error
#   4                              NaN    adagrad             mean_absolute_error
#   ..                             ...        ...                             ...
#   95                        0.422504    adagrad              mean_squared_error
#   96                        0.444797   adadelta              mean_squared_error
#   97                             NaN    rmsprop  mean_squared_logarithmic_error
#   98                        0.415976       adam              mean_squared_error
#   99                        0.398225    rmsprop              mean_squared_error
#
#            score  data_set_index
#   0   140.390176               7
#   1   151.702644               7
#   2    16.660140               7
#   3    73.732495               7
#   4   126.516708               7
#   ..         ...             ...
#   95    2.084563               4
#   96    2.071932               4
#   97    2.035555               4
#   98    2.045413               4
#   99    2.031785               4
#
#   [1000 rows x 21 columns],
#   20:     win_size  Número de camadas  Unidades na camada 0  Dropout da camada 0  \
#   0         36                  5                    59             0.310207
#   1         69                  5                    14             0.371315
#   2         20                  5                    42             0.385063
#   3        107                  1                    15             0.187921
#   4         81                  1                    61             0.482333
#   ..       ...                ...                   ...                  ...
#   95        31                  5                    15             0.325505
#   96        63                  4                    22             0.402475
#   97        42                  3                    27             0.298410
#   98        36                  5                    19             0.347006
#   99        57                  1                    45             0.335419
#
#       Dropout recorrente da camada 0  Unidades na camada 1  Dropout da camada 1  \
#   0                         0.434666                  22.0             0.142997
#   1                         0.413199                   8.0             0.367670
#   2                         0.376809                  24.0             0.469053
#   3                         0.105315                   NaN                  NaN
#   4                         0.135807                   NaN                  NaN
#   ..                             ...                   ...                  ...
#   95                        0.446702                  10.0             0.439507
#   96                        0.379417                   7.0             0.476838
#   97                        0.425608                   4.0             0.456617
#   98                        0.390194                  11.0             0.412496
#   99                        0.409447                   NaN                  NaN
#
#       Dropout recorrente da camada 1  Unidades na camada 2  Dropout da camada 2  \
#   0                         0.138732                   6.0             0.181410
#   1                         0.437992                   3.0             0.484392
#   2                         0.240994                   6.0             0.100545
#   3                              NaN                   NaN                  NaN
#   4                              NaN                   NaN                  NaN
#   ..                             ...                   ...                  ...
#   95                        0.375268                   7.0             0.366914
#   96                        0.408529                   5.0             0.445857
#   97                        0.329174                   3.0             0.386716
#   98                        0.350678                   7.0             0.416610
#   99                             NaN                   NaN                  NaN
#
#       ...  Unidades na camada 3  Dropout da camada 3  \
#   0   ...                   4.0             0.241047
#   1   ...                   3.0             0.350178
#   2   ...                   3.0             0.165804
#   3   ...                   NaN                  NaN
#   4   ...                   NaN                  NaN
#   ..  ...                   ...                  ...
#   95  ...                   5.0             0.280190
#   96  ...                   4.0             0.293320
#   97  ...                   NaN                  NaN
#   98  ...                   6.0             0.267499
#   99  ...                   NaN                  NaN
#
#       Dropout recorrente da camada 3  Unidades na camada 4  Dropout da camada 4  \
#   0                         0.255519                   4.0             0.278575
#   1                         0.188481                   3.0             0.434861
#   2                         0.167985                   3.0             0.149970
#   3                              NaN                   NaN                  NaN
#   4                              NaN                   NaN                  NaN
#   ..                             ...                   ...                  ...
#   95                        0.253794                   5.0             0.455162
#   96                        0.173864                   NaN                  NaN
#   97                             NaN                   NaN                  NaN
#   98                        0.236805                   5.0             0.394270
#   99                             NaN                   NaN                  NaN
#
#       Dropout recorrente da camada 4  optimizer                            loss  \
#   0                         0.469457   adadelta              mean_squared_error
#   1                         0.163201       adam  mean_absolute_percentage_error
#   2                         0.132635   adadelta  mean_squared_logarithmic_error
#   3                              NaN    adagrad             mean_absolute_error
#   4                              NaN   adadelta              mean_squared_error
#   ..                             ...        ...                             ...
#   95                        0.179664        sgd              mean_squared_error
#   96                             NaN        sgd              mean_squared_error
#   97                             NaN        sgd              mean_squared_error
#   98                        0.152748        sgd              mean_squared_error
#   99                             NaN    rmsprop              mean_squared_error
#
#            score  data_set_index
#   0   223.079696               7
#   1   101.485307               7
#   2    74.229032               7
#   3    73.113067               7
#   4   277.322526               7
#   ..         ...             ...
#   95    1.943562               4
#   96    2.046540               4
#   97    2.003514               4
#   98    1.979666               4
#   99    2.237520               4
#
#   [1000 rows x 21 columns]}}

# %%
import seaborn as sns
from matplotlib import pyplot as plt
correlations = ['pearson', 'spearman']
for rede in redes:
    for steps_ahead in steps_ahead_list:
        df_encoded = datasets[rede][steps_ahead].apply(lambda col: col.map(lambda x: list(col.values).index(x)) if col.dtype == 'object' else col, axis=0)
        for correlation in correlations:
            plt.figure()
            heatmap = sns.heatmap(df_encoded.corr(method=correlation)[['score']].sort_values(by='score', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
            heatmap.set_title(f'Correlação de {correlation} com o score para a rede {rede}, {steps_ahead} passos à frente')
            plt.show()

# %%
var_df = pd.read_csv(caminho_var)
data_indices = list(var_df['Data_index'].values)
for c in var_df.columns:
    if c != 'Data_index':
        plt.figure()
        plt.title(c)
        plt.hist(var_df[c], bins=50)
        plt.show()

# %%
for steps_ahead in steps_ahead_list:
    var_scores = list(var_df[f'VAR_result ({steps_ahead} steps ahead)'].values)
    fig, ax = plt.subplots()
    bar_width = 1/(len(redes)+1)
    ax.set_title(f'{steps_ahead} steps ahead')
    ax.bar(data_indices, var_scores, bar_width, label="VAR")
    for x, y in zip(data_indices, var_scores):
        plt.annotate("VAR", (x, y))
    for index, rede in enumerate(redes):
        current_x_axis = [x+bar_width*(index+1) for x in data_indices]
        current_net_scores = list(datasets[rede][steps_ahead].groupby('data_set_index')['score'].min().values)
        ax.bar(current_x_axis, current_net_scores, bar_width, label=rede)
        for x, y in zip(current_x_axis, current_net_scores):
            plt.annotate(rede, (x, y))
    plt.show()

# %%
var_summary = pd.DataFrame({'média': var_df.mean(), 'desvio': var_df.std()}).iloc[1:]
var_summary
# Out:
#                                 média    desvio
# VAR_result (1 steps ahead)   0.162287  0.208111
# VAR_result (5 steps ahead)   0.323938  0.429947
# VAR_result (20 steps ahead)  0.624475  0.863060

# %%
nets_summaries = {}
for rede in redes:
    nets_summaries[rede] = {}
    for steps_ahead in steps_ahead_list:
        best_scores_opt = datasets[rede][steps_ahead].groupby('data_set_index')['score'].min()
        nets_summaries[rede][steps_ahead] = pd.Series({
            'Média': best_scores_opt.mean(), 'Desvio': best_scores_opt.std()
        })
        print(rede)
        print(f"{steps_ahead} passos à frente")
        print(nets_summaries[rede][steps_ahead])
# Out:
# CNN
# 1 passos à frente
# Média     0.462484
# Desvio    0.332204
# dtype: float64
# CNN
# 5 passos à frente
# Média     0.464159
# Desvio    0.336657
# dtype: float64
# CNN
# 20 passos à frente
# Média     0.404378
# Desvio    0.282479
# dtype: float64
# LSTM
# 1 passos à frente
# Média     0.959668
# Desvio    0.456181
# dtype: float64
# LSTM
# 5 passos à frente
# Média     1.301471
# Desvio    0.797364
# dtype: float64
# LSTM
# 20 passos à frente
# Média     0.990459
# Desvio    0.494494
# dtype: float64
